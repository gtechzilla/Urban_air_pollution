# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data=pd.read_csv('Train.csv')
test_data=pd.read_csv('Test.csv')

# %%
train_data.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0           769.50            92                             11.000000
# 1          1319.85            91                             14.600000
# 2          1181.96            96                             16.400000
# 3          1113.67            96                              6.911948
# 4          1164.82            95                             13.900001
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle  \
# ...

# %%
test_data.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                             11.600000                          30.200001
# 1                             18.300001                          42.900002
# 2                             17.600000                          41.299999
# 3                             15.011948                          53.100002
# 4                              9.700000                          71.599998
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                            0.00409                    14.656824
# 1                            0.00595                    15.026544
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30557 entries, 0 to 30556
# Data columns (total 82 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Place_ID X Date                                      30557 non-null  object
#  1   Date                                                 30557 non-null  object
#  2   Place_ID                                             30557 non-null  object
#  3   target                                               30557 non-null  float64
#  4   target_min                                           30557 non-null  float64
#  5   target_max                                           30557 non-null  float64
#  6   target_variance                                      30557 non-null  float64
#  7   target_count                                         30557 non-null  int64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16136 entries, 0 to 16135
# Data columns (total 77 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Place_ID X Date                                      16136 non-null  object
#  1   Date                                                 16136 non-null  object
#  2   Place_ID                                             16136 non-null  object
#  3   precipitable_water_entire_atmosphere                 16136 non-null  float64
#  4   relative_humidity_2m_above_ground                    16136 non-null  float64
#  5   specific_humidity_2m_above_ground                    16136 non-null  float64
#  6   temperature_2m_above_ground                          16136 non-null  float64
#  7   u_component_of_wind_10m_above_ground                 16136 non-null  float64
# ...

# %%
#checking for columns not in our train data
for i in test_data.columns:
    if i not in train_data.columns:
        print(i)

# %%
#checking for columns not in our test data
for i in train_data.columns:
    if i not in test_data.columns:
        print(i)
# Out:
# target
# target_min
# target_max
# target_variance
# target_count

# %%
#removing duplicates in our data
train_data=train_data.drop_duplicates()
test_data=test_data.drop_duplicates()

#removing columns with a significant amount of missing data
train_data=train_data.drop(['L3_CH4_CH4_column_volume_mixing_ratio_dry_air','L3_CH4_aerosol_height','L3_CH4_aerosol_optical_depth','L3_CH4_sensor_azimuth_angle','L3_CH4_sensor_zenith_angle','L3_CH4_solar_azimuth_angle','L3_CH4_solar_zenith_angle'],axis=1)
test_data=test_data.drop(['L3_CH4_CH4_column_volume_mixing_ratio_dry_air','L3_CH4_aerosol_height','L3_CH4_aerosol_optical_depth','L3_CH4_sensor_azimuth_angle','L3_CH4_sensor_zenith_angle','L3_CH4_solar_azimuth_angle','L3_CH4_solar_zenith_angle'],axis=1)

# %%
#dropping columns not in test data
train_data2=train_data.drop([
'target',
'target_min',
'target_max',
'target_variance',
'target_count',
'Place_ID X Date',
'L3_NO2_sensor_altitude',
'L3_NO2_sensor_azimuth_angle',
'L3_NO2_sensor_zenith_angle',
'L3_NO2_solar_azimuth_angle',
'L3_NO2_solar_zenith_angle',
'L3_O3_sensor_azimuth_angle',
'L3_O3_sensor_zenith_angle',
'L3_O3_solar_azimuth_angle',
'L3_O3_solar_zenith_angle',
'L3_CO_sensor_altitude',
'L3_CO_sensor_azimuth_angle',
'L3_CO_sensor_zenith_angle',
'L3_CO_solar_azimuth_angle',
'L3_CO_solar_zenith_angle',
'L3_HCHO_sensor_azimuth_angle',
'L3_HCHO_sensor_zenith_angle',
'L3_HCHO_solar_azimuth_angle',
'L3_HCHO_solar_zenith_angle',
'L3_CLOUD_sensor_azimuth_angle',
'L3_CLOUD_sensor_zenith_angle',
'L3_CLOUD_solar_azimuth_angle',
'L3_CLOUD_solar_zenith_angle',
'L3_AER_AI_sensor_altitude',
'L3_AER_AI_sensor_azimuth_angle',
'L3_AER_AI_sensor_zenith_angle',
'L3_AER_AI_solar_azimuth_angle',
'L3_AER_AI_solar_zenith_angle',
'L3_SO2_sensor_azimuth_angle',
'L3_SO2_sensor_zenith_angle',
'L3_SO2_solar_azimuth_angle',
'L3_SO2_solar_zenith_angle'],axis=1)

test_data2=test_data.drop([
'Place_ID X Date',
'L3_NO2_sensor_altitude',
'L3_NO2_sensor_azimuth_angle',
'L3_NO2_sensor_zenith_angle',
'L3_NO2_solar_azimuth_angle',
'L3_NO2_solar_zenith_angle',
'L3_O3_sensor_azimuth_angle',
'L3_O3_sensor_zenith_angle',
'L3_O3_solar_azimuth_angle',
'L3_O3_solar_zenith_angle',
'L3_CO_sensor_altitude',
'L3_CO_sensor_azimuth_angle',
'L3_CO_sensor_zenith_angle',
'L3_CO_solar_azimuth_angle',
'L3_CO_solar_zenith_angle',
'L3_HCHO_sensor_azimuth_angle',
'L3_HCHO_sensor_zenith_angle',
'L3_HCHO_solar_azimuth_angle',
'L3_HCHO_solar_zenith_angle',
'L3_CLOUD_sensor_azimuth_angle',
'L3_CLOUD_sensor_zenith_angle',
'L3_CLOUD_solar_azimuth_angle',
'L3_CLOUD_solar_zenith_angle',
'L3_AER_AI_sensor_altitude',
'L3_AER_AI_sensor_azimuth_angle',
'L3_AER_AI_sensor_zenith_angle',
'L3_AER_AI_solar_azimuth_angle',
'L3_AER_AI_solar_zenith_angle',
'L3_SO2_sensor_azimuth_angle',
'L3_SO2_sensor_zenith_angle',
'L3_SO2_solar_azimuth_angle',
'L3_SO2_solar_zenith_angle',
],axis=1)

# %%
#checking for columns not in our test data
for i in train_data2.columns:
    if i not in test_data2.columns:
        print(i)

# %%
#checking for columns not in our train data
for i in test_data2.columns:
    if i not in train_data2.columns:
        print(i)

# %%
#splitting our date column to year month and day
train_data2['Year']=pd.to_datetime(train_data2['Date']).dt.year
train_data2['Month']=pd.to_datetime(train_data2['Date']).dt.month
train_data2['Day']=pd.to_datetime(train_data2['Date']).dt.day

test_data2['Year']=pd.to_datetime(test_data2['Date']).dt.year
test_data2['Month']=pd.to_datetime(test_data2['Date']).dt.month
test_data2['Day']=pd.to_datetime(test_data2['Date']).dt.day

#dropping our original date column
train_data2=train_data2.drop(['Date'],axis=1)
test_data2=test_data2.drop(['Date'],axis=1)

# %%
train_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30557 entries, 0 to 30556
# Data columns (total 40 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Place_ID                                             30557 non-null  object
#  1   precipitable_water_entire_atmosphere                 30557 non-null  float64
#  2   relative_humidity_2m_above_ground                    30557 non-null  float64
#  3   specific_humidity_2m_above_ground                    30557 non-null  float64
#  4   temperature_2m_above_ground                          30557 non-null  float64
#  5   u_component_of_wind_10m_above_ground                 30557 non-null  float64
#  6   v_component_of_wind_10m_above_ground                 30557 non-null  float64
#  7   L3_NO2_NO2_column_number_density                     28368 non-null  float64
# ...

# %%
#placing data i our X and Y variables 
X=train_data2.drop(['Place_ID'],axis=1)
Y=train_data['target']

# %%
X.shape
# Out:
# (30557, 39)

# %%
Y.shape
# Out:
# (30557,)

# %% [markdown]
# from sklearn.model_selection import train_test_split
# X_train,Y_train,X_test,Y_test=train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
import xgboost
model = xgboost.XGBRegressor(colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.07,
                 max_depth=3,
                 min_child_weight=1.5,
                 n_estimators=10000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=100,)
model.fit(X,Y)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.07, max_delta_step=0, max_depth=3,
#              min_child_weight=1.5, missing=nan, monotone_constraints=None,
#              n_estimators=10000, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=100, reg_alpha=0.75,
#              reg_lambda=0.45, scale_pos_weight=1, seed=100, subsample=0.6,
#              tree_method=None, validate_parameters=False, verbosity=None)

# %%
test_data2.shape
# Out:
# (16136, 40)

# %%
test_data2=test_data2.drop(['Place_ID'],axis=1)
test_data['Prediction'] = model.predict(test_data2)
filename = 'submission_6.csv'
pd.DataFrame({'Place_ID X Date': test_data['Place_ID X Date'], 'target': test_data.Prediction}).to_csv(filename, index=False)
